# %%
import os

os.chdir("../")

# %%
import os

os.chdir("project/Text-Summarizer")

print(os.getcwd())
# Out:
# c:\Users\snehi\OneDrive\Desktop\project\Text-Summarizer

# %%
from pathlib import Path
from textSummarizer.utils.common import read_yaml

config = read_yaml(Path("config/config.yaml"))

print(config)
# Out:
# [2026-08-28 00:31:35,828: INFO: common]: yaml file: config\config.yaml loaded successfully]
# {'artifacts_root': 'artifacts', 'data_ingestion': {'root_dir': 'artifacts/data_ingestion', 'source_URL': 'https://github.com/Sne-hi/datasets/raw/refs/heads/main/samsum%20dataset.zip', 'local_data_file': 'artifacts/data_ingestion/samsum dataset.zip', 'unzip_dir': 'artifacts/data_ingestion/unzip'}}

# %%
try:
    config = ConfigurationManager()

    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(
        config=data_ingestion_config
    )

    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# [2026-08-28 00:32:33,223: INFO: common]: yaml file: config\config.yaml loaded successfully]
# [2026-08-28 00:32:33,227: INFO: common]: yaml file: params.yaml loaded successfully]
# [2026-08-28 00:32:33,230: INFO: common]: created directory at: artifacts]
# [2026-08-28 00:32:33,231: INFO: common]: created directory at: artifacts/data_ingestion]
# [2026-08-28 00:32:35,954: INFO: data_ingestion]: File downloaded successfully: artifacts\data_ingestion\samsum dataset.zip]
# [2026-08-28 00:32:36,181: INFO: data_ingestion]: File extracted successfully to: artifacts\data_ingestion\unzip]
